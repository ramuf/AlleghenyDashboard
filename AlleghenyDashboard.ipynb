# %%
import pandas as pd
# import plotly.graph_objects as go

# %%
alle_df = pd.read_csv('covid-19-allegheny.csv')

# %%
alle_df.head()
# Out:
#    Unnamed: 0        date     county         state  cases  deaths  population  \
# 0        2208  2020-03-14  Allegheny  Pennsylvania      1       0     1216045
# 1        2628  2020-03-15  Allegheny  Pennsylvania      3       0     1216045
# 2        3093  2020-03-16  Allegheny  Pennsylvania      5       0     1216045
# 3        3622  2020-03-17  Allegheny  Pennsylvania     10       0     1216045
# 4        4238  2020-03-18  Allegheny  Pennsylvania     12       0     1216045
#
#    new_cases  new_deaths  new_cases_smoothed  deaths_poll  cases_fatality  \
# 0        NaN         NaN                 NaN          0.0             0.0
# 1        2.0         0.0                 NaN          0.0             0.0
# 2        2.0         0.0                 NaN          0.0             0.0
# 3        5.0         0.0                 NaN          0.0             0.0
# 4        2.0         0.0                 NaN          0.0             0.0
#
#    daily_incidence  7_days_incidence
# ...
